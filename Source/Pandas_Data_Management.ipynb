# %%
import pandas as pd
from datasets import load_dataset
import matplotlib.pyplot as plt 

#Load Data
dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()

#Data Cleanup
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])

# %%
df.sample(10)
# Out:
#              job_title_short                                job_title  \
# 429757        Data Scientist                           Data Scientist
# 185631          Data Analyst                    Data  Analyst Pricing
# 448981         Data Engineer         Data Engineer - Java/Spark/Kafka
# 749810  Senior Data Engineer                     Senior Data Engineer
# 169848         Data Engineer                            Data Engineer
# 265009        Data Scientist                   Manager - Data Science
# 43290       Business Analyst  Bilingual Business Intelligence Analyst
# 676700          Data Analyst    Sales Data Integrity Analyst (Hybrid)
# 229828   Senior Data Analyst       JSF - Senior Business Data Analyst
# 732559          Data Analyst              Data Analyst - Direct Hire!
#
#             job_location                job_via job_schedule_type  \
# 429757  Hamburg, Germany  via BeBee Deutschland         Full-time
# 185631  Lisbon, Portugal           via LinkedIn         Full-time
# 448981        London, UK           via JobServe        Contractor
# 749810     Madrid, Spain              via BeBee         Full-time
# 169848        Durham, NC           via LinkedIn        Contractor
# 265009      San Jose, CA        via Trabajo.org         Full-time
# 43290             Canada       via BeBee Canada         Full-time
# 676700      Columbia, MD           via LinkedIn         Full-time
# 229828     Arlington, TX              via BeBee         Full-time
# 732559  Santa Monica, CA               via Jora         Full-time
#
#         job_work_from_home            search_location     job_posted_date  \
# 429757               False                    Germany 2023-04-22 16:11:39
# 185631               False                   Portugal 2023-09-25 15:38:01
# 448981               False             United Kingdom 2023-09-04 14:12:13
# 749810               False                      Spain 2023-01-04 05:58:57
# 169848               False  California, United States 2023-05-02 15:09:50
# 265009               False  California, United States 2023-04-30 07:03:03
# 43290                False                     Canada 2023-09-01 06:41:52
# 676700               False    New York, United States 2023-08-24 10:01:31
# 229828               False       Texas, United States 2023-09-07 07:01:30
# 732559               False  California, United States 2023-01-23 21:01:24
#
#         job_no_degree_mention  job_health_insurance     job_country  \
# 429757                  False                 False         Germany
# 185631                  False                 False        Portugal
# 448981                   True                 False  United Kingdom
# 749810                   True                 False           Spain
# 169848                  False                 False   United States
# 265009                  False                 False   United States
# 43290                   False                 False          Canada
# 676700                  False                 False   United States
# 229828                  False                  True   United States
# 732559                   True                 False   United States
#
#        salary_rate  salary_year_avg  salary_hour_avg  \
# 429757        None              NaN              NaN
# 185631        None              NaN              NaN
# 448981        None              NaN              NaN
# 749810        None              NaN              NaN
# 169848        None              NaN              NaN
# 265009        None              NaN              NaN
# 43290         None              NaN              NaN
# 676700        None              NaN              NaN
# 229828        None              NaN              NaN
# 732559        None              NaN              NaN
#
#                       company_name  \
# 429757                  adjoe GmbH
# 185631                     AUTODOC
# 448981                Norton Blake
# 749810                      Cabify
# 169848  VMC Soft Technologies, Inc
# 265009             IT commence llc
# 43290              McKesson Europe
# 676700                    Ambu A/S
# 229828    Integrated Data Services
# 732559              Robert Half US
#
#                                                job_skills  \
# 429757  ['sql', 'python', 'r', 'scala', 'aws', 'redshi...
# 185631  ['sql', 'python', 'r', 'power bi', 'tableau', ...
# 448981                ['java', 'scala', 'kafka', 'spark']
# 749810  ['scala', 'golang', 'python', 'go', 'aws', 'gc...
# 169848  ['sql', 'r', 'python', 'oracle', 'snowflake', ...
# 265009  ['sas', 'sas', 'r', 'python', 'aws', 'azure', ...
# 43290                                           ['excel']
# 676700                       ['sql', 'excel', 'power bi']
# 229828                    ['qlik', 'tableau', 'power bi']
# 732559                           ['sql', 'go', 'tableau']
#
#                                           job_type_skills
# 429757  {'cloud': ['aws', 'redshift'], 'libraries': ['...
# 185631  {'analyst_tools': ['power bi', 'tableau', 'exc...
# 448981  {'libraries': ['kafka', 'spark'], 'programming...
# 749810  {'cloud': ['aws', 'gcp', 'azure', 'bigquery'],...
# 169848  {'analyst_tools': ['alteryx', 'qlik', 'tableau...
# 265009  {'analyst_tools': ['sas'], 'cloud': ['aws', 'a...
# 43290                        {'analyst_tools': ['excel']}
# 676700  {'analyst_tools': ['excel', 'power bi'], 'prog...
# 229828  {'analyst_tools': ['qlik', 'tableau', 'power b...
# 732559  {'analyst_tools': ['tableau'], 'programming': ...

# %%
df_altered =  df.copy()

# %%
id(df) == id(df_altered)
# Out:
# False
